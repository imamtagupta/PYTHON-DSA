# %% [markdown]
# ###  Build Array from Permutation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def buildFromPermutation(arr):
    n - len(arr)
    op = [0]*n
    for i in range(n):
        op[i] = arr[arr[i]]
    return op

# %%
buildFromPermutation([0,2,1,5])
